# %% [markdown]
# DATA PREPRATION AND ML

# %% [markdown]
# HANDLING MISSING DATA

# %%
import numpy as np
import pandas as pd
data = {
    "Age" :[22,25,np.nan,30,28],
    #nan not a number.
    "Salary" :[30000,35000,40000,np.nan,38000],
    "Gender" :["Male","Female","Female","Male",np.nan],
    "Department" :["HR","IT","Finance","IT","HR"],
    "Purchased":["Yes","No","Yes","No","Yes"]
}
df = pd.DataFrame(data)
df
df.isnull()
df.isnull().sum()
